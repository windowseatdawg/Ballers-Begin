# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/Users/WSD/Desktop/B Side/Untitled Folder/Football Dataset/Modric Final.csv')
df2 = pd.read_csv('/Users/WSD/Desktop/B Side/Untitled Folder/Football Dataset/Muller Final.csv')

# %%
df1.head()
#df2.head()
# Out:
#       Season  MP   Gls   Ast   G+A
# 0  2008-2009  38  0.12  0.23  0.32
# 1  2009-2010  25  0.14  0.14  0.28
# 2  2010-2011  40  0.11  0.08  0.19
# 3  2011-2012  38  0.14  0.11  0.24
# 4  2012-2013  44  0.13  0.13  0.26

# %%
plt.plot(df1['Season'],df1['Gls'],'s-.',color='b',label = "modric")
plt.xlabel("Seasons")
plt.ylabel("GIs")
plt.plot(df2['Season'],df2['Gls'],'s-.',color='r',label = "muller")
plt.legend()

# %%
plt.plot(df1['Season'],df1['Ast'],'s-.',color='b',label = "modric")
plt.xlabel("Seasons")
plt.ylabel("Ast")
plt.plot(df2['Season'],df2['Ast'],'s-.',color='r',label = "muller")
plt.legend()

# %%
plt.plot(df1['Season'],df1['G+A'],'s-.',color='b',label = "modric")
plt.xlabel("Seasons")
plt.ylabel("G+A")
plt.plot(df2['Season'],df2['G+A'],'s-.',color='r',label = "muller")
plt.legend()
