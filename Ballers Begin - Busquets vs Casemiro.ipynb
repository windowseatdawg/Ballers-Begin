# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/Users/WSD/Desktop/B Side/Untitled Folder/Football Dataset/Busquets Defence.csv')
df2 = pd.read_csv('/Users/WSD/Desktop/B Side/Untitled Folder/Football Dataset/Casemiro Defence.csv')
df3 = pd.read_csv('/Users/WSD/Desktop/B Side/Untitled Folder/Football Dataset/Busquets Passing.csv')
df4 = pd.read_csv('/Users/WSD/Desktop/B Side/Untitled Folder/Football Dataset/Casemiro Passing.csv')

# %%
df1.head()
#df2.head()
# Out:
#       Season  Tkl  Press  Blocks
# 0  2017-2018   67    746      50
# 1  2018-2019   80    758      71
# 2  2019-2020   78    491      52
# 3  2020-2021   46    347      29

# %%
plt.plot(df1['Season'],df1['Tkl'],'s-.',color='b',label = "busquets")
plt.xlabel("Seasons")
plt.ylabel("Tackles")
plt.plot(df2['Season'],df2['Tkl'],'s-.',color='r',label = "casemiro")
plt.legend()

# %%
plt.plot(df1['Season'],df1['Press'],'s-.',color='b',label = "busquets")
plt.xlabel("Seasons")
plt.ylabel("Press")
plt.plot(df2['Season'],df2['Press'],'s-.',color='r',label = "casemiro")
plt.legend()

# %%
plt.plot(df1['Season'],df1['Blocks'],'s-.',color='b',label = "busquets")
plt.xlabel("Seasons")
plt.ylabel("Blocks")
plt.plot(df2['Season'],df2['Blocks'],'s-.',color='r',label = "casemiro")
plt.legend()

# %%
plt.plot(df3['Season'],df3['Cmp'],'s-.',color='b',label = "busquets")
plt.xlabel("Seasons")
plt.ylabel("Completed Passes")
plt.plot(df4['Season'],df4['Cmp'],'s-.',color='r',label = "casemiro")
plt.legend()

# %%
plt.plot(df3['Season'],df3['TotDist'],'s-.',color='b',label = "busquets")
plt.xlabel("Seasons")
plt.ylabel("Total distance traveled by passes")
plt.plot(df4['Season'],df4['TotDist'],'s-.',color='r',label = "casemiro")
plt.legend()

# %%
plt.plot(df3['Season'],df3['PrgDist'],'s-.',color='b',label = "busquets")
plt.xlabel("Seasons")
plt.ylabel("Progressive distance traveled by passes")
plt.plot(df4['Season'],df4['PrgDist'],'s-.',color='r',label = "casemiro")
plt.legend()
